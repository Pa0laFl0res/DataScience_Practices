# %% [markdown]
# <a href="https://colab.research.google.com/github/Pa0laFl0res/DataScience_Practices/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando base de datos

# %%
import pandas as pd

# %%
pd.read_csv('credit_card.csv')
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos = pd.read_csv('credit_card.csv')

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# Traduciendo variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columns = {
    'LIMIT_BAL' : 'límite', 
    'CHECKING_ACCOUNT' : 'cuenta_corriente', 
    'EDUCATION' : 'escolaridad', 
    'MARRIAGE' : 'estado_civil', 
    'AGE' : 'edad',
    'BILL_AMT' : 'valor_factura', 
    'PAY_AMT' : 'valor_pago', 
    'DEFAULT' : 'moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columns)

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes' : 'Sí',
    'No' : 'No'
}

# %%
tarjetas.cuenta_corriente.map(dic_cuenta)
# Out:
# 0       Sí
# 1       Sí
# 2       Sí
# 3       Sí
# 4       No
#         ..
# 1495    Sí
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(dic_cuenta)

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               Sí       2.University      Married    24
# 1   36132               Sí       2.University       Single    26
# 2   27099               Sí       2.University       Single    34
# 3   15055               Sí       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University': '2.Universidad', 
    '3.Graduate School' : '3.Pos-graduación', 
    '1.High School' : '1.Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(dic_escolaridad)

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad      Married    24
# 1   36132               Sí     2.Universidad       Single    26
# 2   27099               Sí     2.Universidad       Single    34
# 3   15055               Sí     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married' : 'Casado/a',
    'Single' : 'Soltero/a'
}

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(dic_estado_civil)

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Importando Seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno, pandas-profiling

# %%
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# # Análisis 1

# %%
sns.distplot(tarjetas['límite'])
# Out:
# <ipython-input-30-c50e90844e4f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tarjetas['límite'])
# <Axes: xlabel='límite', ylabel='Density'>

# %%
sns.displot(data = tarjetas, x = 'límite')

# %%
sns.displot(data = tarjetas, x = 'límite');

# %%
sns.displot(data = tarjetas, x = 'límite', hue = 'escolaridad');

# %% [markdown]
# # Análisis 2

# %%
tarjetas['iu'] = tarjetas['valor_factura'] / tarjetas['límite']

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.displot(data = tarjetas, x = 'iu')

# %% [markdown]
# Hay un público significativo que usa poco del límite que tienen disponible

# %% [markdown]
# Estilos y colores

# %%
sns.set_style('darkgrid')

# %%
sns.displot(data = tarjetas, x = 'límite', hue = 'escolaridad');

# %% [markdown]
# # Análisis de variable categóricas

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.countplot(x = 'cuenta_corriente', data = tarjetas);

# %%
sns.countplot(x = 'cuenta_corriente', data = tarjetas, hue = 'moroso');

# %%
sns.countplot(x = 'cuenta_corriente', data = tarjetas, hue = 'moroso', palette = 'coolwarm');

# %%
sns.catplot(x = 'estado_civil', y = 'límite', data = tarjetas);

# %%
sns.catplot(x = 'estado_civil', y = 'límite', data = tarjetas, hue = 'moroso');

# %%
sns.catplot(x = 'estado_civil', y = 'límite', data = tarjetas, hue = 'moroso', dodge = True);

# %%
sns.swarmplot(x = 'escolaridad', data = tarjetas);
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 44.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x = 'escolaridad', y = 'iu', data = tarjetas);

# %%
sns.swarmplot(x = 'escolaridad', data = tarjetas, hue = 'moroso');
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 44.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = 'escolaridad', data = tarjetas, hue = 'moroso', palette = 'bone');
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 44.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x = 'escolaridad', y = 'iu', data = tarjetas);

# %%
sns.violinplot(x = 'escolaridad', y = 'iu', data = tarjetas, hue = 'moroso');

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
tarjetas.edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
bins = [20, 30, 40, 50, 100]
nombres = ['20-30', '30-40', '40-50', '50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['edad'], bins, labels = nombres)

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.boxplot(x = 'rango_edad', y = 'límite', data = tarjetas);

# %% [markdown]
# # Análisis de variables numéricas

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.displot(data = tarjetas, x = 'límite', hue = 'escolaridad');

# %%
sns.displot(data = tarjetas, x = 'límite', col = 'escolaridad');

# %%
sns.displot(data = tarjetas, x = 'límite', col = 'escolaridad', kind = 'kde');

# %%
sns.displot(data = tarjetas, x = 'límite', col = 'escolaridad', kind = 'kde', hue = 'moroso');

# %%
sns.displot(data = tarjetas, x = 'límite', col = 'escolaridad', kind = 'kde', hue = 'rango_edad');

# %% [markdown]
# Dispersión

# %%
sns.scatterplot(x = 'iu', y = 'valor_factura', data = tarjetas);

# %%
sns.scatterplot(x = 'iu', y = 'valor_factura', data = tarjetas, hue = 'cuenta_corriente');

# %%
sns.lmplot(x = 'iu', y = 'valor_factura', data = tarjetas);

# %% [markdown]
# Test de hipótesis

# %%
sns.lmplot(x = 'iu', y = 'valor_factura', data = tarjetas, col = 'moroso');

# %%
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<sup>
#
# La distribución de los grupos moroso y no moroso es la misma

# %% [markdown]
# H<sup>alt<sup>
#
# La distribución de los grupos moroso y no moroso no es la misma

# %%
moroso = tarjetas.query('moroso == 1').valor_factura

# %%
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: valor_factura, Length: 117, dtype: float64

# %%
no_moroso = tarjetas.query('moroso == 1').valor_factura

# %%
no_moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: valor_factura, Length: 117, dtype: float64

# %%
resultado = ranksums(moroso, no_moroso)

# %%
print('El p_value de nuestro test es {}'.format(resultado.pvalue))
# Out:
# El p_value de nuestro test es 1.0

# %% [markdown]
# # Jointplot

# %%
tarjetas.head()
# Out:
#    límite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Sí     2.Universidad     Casado/a    24
# 1   36132               Sí     2.Universidad    Soltero/a    26
# 2   27099               Sí     2.Universidad    Soltero/a    34
# 3   15055               Sí     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.jointplot(x = 'edad', y = 'límite', data = tarjetas);

# %%
sns.jointplot(x = 'edad', y = 'límite', data = tarjetas, kind = 'kde');

# %%
sns.jointplot(x = 'edad', y = 'límite', data = tarjetas, kind = 'hex');

# %%
sns.jointplot(x = 'edad', y = 'límite', data = tarjetas, kind = 'kde', hue = 'moroso');

# %% [markdown]
# # Pairplot

# %%
tarjetas.describe()
# Out:
#               límite         edad  valor_factura    valor_pago       moroso  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#                 iu
# count  1500.000000
# mean      0.388237
# std       0.341923
# min       0.000188
# 25%       0.049209
# 50%       0.308976
# 75%       0.704090
# max       0.998010

# %%
sns.pairplot(data = tarjetas);

# %%
sns.pairplot(data = tarjetas, hue = 'escolaridad', palette = 'cividis');
