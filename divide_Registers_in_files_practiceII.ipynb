# %% [markdown]
# <a href="https://colab.research.google.com/github/Pa0laFl0res/DataScience_Practices/blob/main/divide_Registers_in_files_practiceII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("people_n_tasks.xlsx")
df
# Out:
#              ID             Name       Title    EmployeeType  \
# 0      KMCMAHON   Mcmahon, Karyn  CONSULTANT      CONSULTANT
# 1       CBRYANT  Bryant, Carolyn  CONSULTANT          SALARY
# 2        PLUCAS    Lucas, Pamela       SALES  ADMINISTRATION
# 3      ASHIELDS     Shields, Art       ADMIN  ADMINISTRATION
# 4       BFRANCO   Franco, Brenda       ADMIN  ADMINISTRATION
# ...         ...              ...         ...             ...
# 2834     JDAGES      Dages, Jeff  CONSULTANT          HOURLY
# 2835   SBOTTOMS   Bottoms, Sandy  CONSULTANT  SUB-CONTRACTOR
# 2836    MFARRIS     Farris, Matt  CONSULTANT          SALARY
# 2837  CSTERLING  Sterling, Chass  CONSULTANT  SUB-CONTRACTOR
# 2838    JRAMSEY    Ramsey, Jorge  CONSULTANT          SALARY
#
#                  TermDate   HireDate   Location
# 0     1900-01-01 00:00:00 1900-01-01  Charlotte
# 1     2015-05-15 00:00:00 1900-01-01  Charlotte
# 2     1900-01-01 00:00:00 1900-01-01  Charlotte
# ...

# %%
df.Location.unique()
# Out:
# array(['Charlotte', 'Nashville', 'Cleveland'], dtype=object)

# %%
df["Location"] == "Cleveland"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2834    False
# 2835    False
# 2836    False
# 2837    False
# 2838    False
# Name: Location, Length: 2839, dtype: bool

# %%
df[df["Location"] == "Cleveland"]
# Out:
#              ID              Name         Title    EmployeeType  \
# 911     LTANNER      Tanner, Lino    CONSULTANT  SUB-CONTRACTOR
# 912     SCHURCH   Church, Stephen  DELIVERY MGR  ADMINISTRATION
# 913      YBURCH     Burch, Yvette    CONSULTANT  SUB-CONTRACTOR
# 914     JMORENO     Moreno, Jamey    CONSULTANT  SUB-CONTRACTOR
# 915        IROY        Roy, Ivory    CONSULTANT  SUB-CONTRACTOR
# ...         ...               ...           ...             ...
# 2807     KBLAIR       Blair, Kari    CONSULTANT          SALARY
# 2808  DWHITAKER  Whitaker, Dennis    CONSULTANT  SUB-CONTRACTOR
# 2809    AHARMON     Harmon, Andre    CONSULTANT          SALARY
# 2810    KWALTON  Walton, Kendrick    CONSULTANT  SUB-CONTRACTOR
# 2811     AKIRBY    Kirby, Armando    CONSULTANT      CONSULTANT
#
#                  TermDate   HireDate   Location
# 911   2004-02-29 00:00:00 1900-01-01  Cleveland
# 912   2018-03-02 00:00:00 1900-01-01  Cleveland
# 913   1900-01-01 00:00:00 1900-01-01  Cleveland
# ...

# %%
for i in df.Location.unique():
  df2 = df[df["Location"] == i]
  print(df2)
# Out:
#              ID              Name       Title    EmployeeType  \
# 0      KMCMAHON    Mcmahon, Karyn  CONSULTANT      CONSULTANT
# 1       CBRYANT   Bryant, Carolyn  CONSULTANT          SALARY
# 2        PLUCAS     Lucas, Pamela       SALES  ADMINISTRATION
# 3      ASHIELDS      Shields, Art       ADMIN  ADMINISTRATION
# 4       BFRANCO    Franco, Brenda       ADMIN  ADMINISTRATION
# ...         ...               ...         ...             ...
# 2786       SROY          Roy, Sal  CONSULTANT          SALARY
# 2796  DBAUTISTA  Bautista, Damion  CONSULTANT  SUB-CONTRACTOR
# 2797    LPORTER   Porter, Loretta  CONSULTANT  SUB-CONTRACTOR
# 2799  AFLETCHER    Fletcher, Anne  CONSULTANT          SALARY
# 2804      DWARE      Ware, Daphne  CONSULTANT          HOURLY
#
#                  TermDate   HireDate   Location
# 0     1900-01-01 00:00:00 1900-01-01  Charlotte
# 1     2015-05-15 00:00:00 1900-01-01  Charlotte
# 2     1900-01-01 00:00:00 1900-01-01  Charlotte
# ...

# %%
for i in df.Location.unique():
  df2 = df[df["Location"] == i]
  df2.to_excel(f"{i}.xlsx", index = False)
